# %% [markdown]
# # 06. Naver API

# %% [markdown]
# ## 1. 네이버 API 사용 등록

# %% [markdown]
# - 네이버 개발자 센터 (https://developers.naver.com/main/)
# - https://developers.naver.com/products/service-api/datalab/datalab.md
# - Application
#     - 어플리케이션 등록
#     - 어플리케이션 이름 ds_study
#     - 사용 API
#         - 검색
#         - 데이터랩(검색어트렌드)
#         - 데이터랩(쇼핑인사이트)
#     - 환경추가
#         - WEB 설정
#         - http://localhost
#     - Client ID : OY1m07J2SdO3Lnw9U90A
#     - Client Secret : bfAANJvlIc
#     - https://developers.naver.com/apps/#/myapps/OY1m07J2SdO3Lnw9U90A/overview

# %% [markdown]
# - urllib : http 프로토콜에 따라서 서버의 요청/응답을 처리하기 위한 모듈
# - urllib.request : 클라이언트의 요청을 처리하는 모듈
# - urllib.parse : url 주소에 대한 분석

# %%
# 네이버 검색 API 예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올림.
# 네이버 검색 Open API 예제 - 블로그 검색
import set_matplotlib_hangul
import os
import sys
import urllib.request

client_id = "OY1m07J2SdO3Lnw9U90A"
client_secret = "bfAANJvlIc"

encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# Hangul OK in your Windows!!!
# {
# 	"lastBuildDate":"Fri, 14 Jul 2023 12:20:03 +0900",
# 	"total":399373,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>파이썬<\/b> 학원 다녀본 후기",
# 			"link":"https:\/\/blog.naver.com\/wkddpfka1\/223123747880",
# 			"description":"취업을 위해서 <b>파이썬<\/b> 독학을 했는데요. 전공자가 아니라 기본기부터 헷갈린다는 문제가 있었어요. 하지만 <b>파이썬<\/b> 학원을 다니며 해결되었어요. 제가 다니고 있는 KIC 캠퍼스에요. 교재 하나 들고 유튜브... ",
# 			"bloggername":"우당탕탕 자취생 블로그",
# 			"bloggerlink":"blog.naver.com\/wkddpfka1",
# 			"postdate":"20230608"
# 		},
# 		{
# 			"title":"국비지원무료교육 <b>파이썬<\/b> 취업 연계 과정",
# 			"link":"https:\/\/blog.naver.com\/notgloom\/223154195272",
# 			"description":"많은 <b>파이썬<\/b>을 배우자는 생각을 하게 되었습니다. Hrd-net을 통해 알아보던 중 국비지원무료교육 <b>파이썬<\/b> 취업 연계 과정이 있다는 것을 알게 되었고, 비용과 취업을 동시에 해결할 수 있는 수업이기에 학원으로... ",
# 			"bloggername":"Cloud_shop ~☆",
# 			"bloggerlink":"blog.naver.com\/notgloom",
# 			"postdate":"20230712"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>학원을 다니면서 공부해야하는 이유",
# ...

# %%
response, response.getcode(), response.code, response.status
# Out:
# (<http.client.HTTPResponse at 0x2029249b400>, 200, 200, 200)

# %%
# 글자로 읽을 경우, decode uft-8 설정
print(response_body.decode("utf-8"))
# Out:
# {
# 	"lastBuildDate":"Fri, 14 Jul 2023 12:20:03 +0900",
# 	"total":399373,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>파이썬<\/b> 학원 다녀본 후기",
# 			"link":"https:\/\/blog.naver.com\/wkddpfka1\/223123747880",
# 			"description":"취업을 위해서 <b>파이썬<\/b> 독학을 했는데요. 전공자가 아니라 기본기부터 헷갈린다는 문제가 있었어요. 하지만 <b>파이썬<\/b> 학원을 다니며 해결되었어요. 제가 다니고 있는 KIC 캠퍼스에요. 교재 하나 들고 유튜브... ",
# 			"bloggername":"우당탕탕 자취생 블로그",
# 			"bloggerlink":"blog.naver.com\/wkddpfka1",
# 			"postdate":"20230608"
# 		},
# 		{
# 			"title":"국비지원무료교육 <b>파이썬<\/b> 취업 연계 과정",
# 			"link":"https:\/\/blog.naver.com\/notgloom\/223154195272",
# 			"description":"많은 <b>파이썬<\/b>을 배우자는 생각을 하게 되었습니다. Hrd-net을 통해 알아보던 중 국비지원무료교육 <b>파이썬<\/b> 취업 연계 과정이 있다는 것을 알게 되었고, 비용과 취업을 동시에 해결할 수 있는 수업이기에 학원으로... ",
# 			"bloggername":"Cloud_shop ~☆",
# 			"bloggerlink":"blog.naver.com\/notgloom",
# 			"postdate":"20230712"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>학원을 다니면서 공부해야하는 이유",
# ...

# %% [markdown]
# ## 검색 : 책(book)

# %%
import os
import sys
import urllib.request

client_id = "OY1m07J2SdO3Lnw9U90A"
client_secret = "bfAANJvlIc"

encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/book?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 14 Jul 2023 12:20:03 +0900",
# 	"total":893,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"프로그래머스 코딩 테스트 문제 풀이 전략: 파이썬 편 (핵심 개념, 81개 문제풀이, 코딩전문역량인증시험(PCCP) 대비까지!)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/37828255619",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3782825\/37828255619.20230704084128.jpg",
# 			"author":"김범수",
# 			"discount":"36000",
# 			"publisher":"길벗",
# 			"pubdate":"20230223",
# 			"isbn":"9791140702893",
# ...

# %% [markdown]
# ## 검색 : 카페(cafeteria)

# %%
import os
import sys
import urllib.request

client_id = "OY1m07J2SdO3Lnw9U90A"
client_secret = "bfAANJvlIc"

encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/cafearticle?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 14 Jul 2023 12:20:03 +0900",
# 	"total":168770,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>파이썬<\/b> 하실 분 계실까요?",
# 			"link":"http:\/\/cafe.naver.com\/isajime\/5573710",
# 			"description":"혼자 <b>파이썬<\/b> 공부하려니 심심하고 진도가 잘 안나가네요. ㅎㅎ 프로그래밍 언어라 많이 어려워서... 왜 <b>파이썬<\/b>을 하고 싶은지 댓글로 남겨주시면 오래 같이 하실분을 컨텍할까 하는데요( 좀 그런가요? ㅎㅎ) 아무도 지원... ",
# 			"cafename":"고.우.리 일산아지매",
# 			"cafeurl":"https:\/\/cafe.naver.com\/isajime"
# 		},
# 		{
# 			"title":"아두이노와 <b>파이썬<\/b> 직렬통신 질문이요",
# 			"link":"http:\/\/cafe.naver.com\/arduinostory\/150994",
# 			"description":"아두이노 ide로 업로드는 했는데 <b>파이썬<\/b>에서 업로드가 안 됩니다 Linking .pio... 1 계속 이 오류가 뜨네요. 아두이노와 <b>파이썬<\/b> 직렬 통신을 하려고 합니다 최종적으로",
# 			"cafename":"아두이노 스토리",
# 			"cafeurl":"https:\/\/cafe.naver.com\/arduinostory"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b> 프로그래밍 초보자도 가능한 이유!",
# 			"link":"http:\/\/cafe.naver.com\/winspec\/556447",
# ...

# %% [markdown]
# ## 검색 : 쇼핑(shopping)

# %%
import os
import sys
import urllib.request

client_id = "OY1m07J2SdO3Lnw9U90A"
client_secret = "bfAANJvlIc"

encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 14 Jul 2023 12:20:03 +0900",
# 	"total":141223,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"Do it 점프 투 <b>파이썬<\/b> 프로그래밍 언어 책 코딩",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=40923069997",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4092306\/40923069997.jpg",
# 			"lprice":"19800",
# 			"hprice":"",
# 			"mallName":"인터파크쇼핑",
# 			"productId":"40923069997",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"출산\/육아",
# 			"category2":"교구",
# 			"category3":"학습교구",
# 			"category4":"기타교구"
# 		},
# 		{
# 			"title":"[길벗]<b>파이썬<\/b> 무작정 따라하기[1017218036]",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=34118710994",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3411871\/34118710994.jpg",
# 			"lprice":"13830",
# 			"hprice":"",
# 			"mallName":"위메프",
# 			"productId":"34118710994",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# ...

# %% [markdown]
# ## 검색 : 백과사전(encyc)

# %%
import os
import sys
import urllib.request

client_id = "OY1m07J2SdO3Lnw9U90A"
client_secret = "bfAANJvlIc"

encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/encyc?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 14 Jul 2023 12:20:03 +0900",
# 	"total":42,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>파이썬<\/b>",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3580815&cid=59088&categoryId=59096",
# 			"description":"‘<b>파이썬<\/b>’이다. 간결한 문법으로 입문자가 이해하기 쉽고, 다양한 분야에 활용할 수 있기 때문이다. 이 외에도 <b>파이썬<\/b>은 머신러닝, 그래픽, 웹 개발 등 여러 업계에서 선호하는 언어로 꾸준히... ",
# 			"thumbnail":"http:\/\/openapi-dbscthumb.phinf.naver.net\/4749_000_1\/20170118193349632_0CHSSS5Y6.png\/01_16.png?type=m160_160"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3607513&cid=58598&categoryId=59316",
# 			"description":" 컴퓨터 언어의 일종으로 간결하고 생산성 높은 프로그래밍 언어.  <b>파이썬<\/b>(python)은 프로그램을 설계하는 프로그래밍 언어 중 하나입니다. 컴퓨터는 0과 1을(이진수) 인식하여 작동하기 때문에 과거에는... ",
# 			"thumbnail":"http:\/\/openapi-dbscthumb.phinf.naver.net\/4751_000_3\/20170710213206672_OPHLG2VOW.jpg\/992_170575_10034.jpg?type=m160_160"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>",
# ...

# %% [markdown]
# ## 3. 상품 검색
# - "몰스킨"

# %%
import os
import sys
import urllib.request

client_id = "OY1m07J2SdO3Lnw9U90A"
client_secret = "bfAANJvlIc"

encText = urllib.parse.quote("몰스킨") #한글을 디코딩?
url = "https://openapi.naver.com/v1/search/shop?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 14 Jul 2023 12:20:04 +0900",
# 	"total":26894,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>몰스킨<\/b> 2024 위클리 18개월 다이어리 소프트커버 상품선택",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=39992373021",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3999237\/39992373021.20230513055543.jpg",
# 			"lprice":"32890",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"39992373021",
# 			"productType":"1",
# 			"brand":"몰스킨",
# 			"maker":"몰스킨",
# 			"category1":"생활\/건강",
# 			"category2":"문구\/사무용품",
# 			"category3":"다이어리\/플래너",
# 			"category4":"다이어리"
# 		},
# 		{
# 			"title":"<b>몰스킨<\/b> 클래식노트 플레인 소프트커버 포켓 Pocket",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=30656121375",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3065612\/30656121375.20220124025746.jpg",
# 			"lprice":"21840",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"30656121375",
# 			"productType":"1",
# ...

# %% [markdown]
# ### (1) gen_search_url()

# %% [markdown]
# ```
# encText = urllib.parse.quote("몰스킨")
# url = "https://openapi.naver.com/v1/search/shop?query=" + encText
# ```

# %%
def gen_search_url(api_node, search_text, start_num, disp_num):
    base = "https://openapi.naver.com/v1/search"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)

    return base + node + param_query + param_start + param_disp

# %%
gen_search_url("shop", "TEST", 10, 3)
# Out:
# 'https://openapi.naver.com/v1/search/shop.json?query=TEST&start=10&display=3'

# %% [markdown]
# ## (2) get_result_onepage()

# %%
import json
import datetime

def get_result_onepage(url):
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    print("[%s] Url Request Success" % datetime.datetime.now())
    return json.loads(response.read().decode("utf-8"))

# %%
url = gen_search_url("shop", "몰스킨", 1, 5)
one_result = get_result_onepage(url)
# Out:
# [2023-07-14 12:20:06.265507] Url Request Success

# %%
one_result
# Out:
# {'lastBuildDate': 'Fri, 14 Jul 2023 12:20:04 +0900',
#  'total': 26894,
#  'start': 1,
#  'display': 5,
#  'items': [{'title': '<b>몰스킨</b> 2024 위클리 18개월 다이어리 소프트커버 상품선택',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=39992373021',
#    'image': 'https://shopping-phinf.pstatic.net/main_3999237/39992373021.20230513055543.jpg',
#    'lprice': '32890',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '39992373021',
#    'productType': '1',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '<b>몰스킨</b> 클래식노트 플레인 소프트커버 포켓 Pocket',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=30656121375',
#    'image': 'https://shopping-phinf.pstatic.net/main_3065612/30656121375.20220124025746.jpg',
#    'lprice': '21840',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '30656121375',
#    'productType': '1',
#    'brand': '몰스킨',
# ...

# %%
one_result["items"][0]["title"] #json key : value 형태이고 여기선 키밸류가 리스트로 달려있다.
# Out:
# '<b>몰스킨</b> 2024 위클리 18개월 다이어리 소프트커버 상품선택'

# %%
one_result["items"][0]["lprice"]
# Out:
# '32890'

# %%
one_result["items"][0]["mallName"]
# Out:
# '네이버'

# %% [markdown]
# ## (2) get_fields()

# %%
one_result["items"][0]
# Out:
# {'title': '<b>몰스킨</b> 2024 위클리 18개월 다이어리 소프트커버 상품선택',
#  'link': 'https://search.shopping.naver.com/gate.nhn?id=39992373021',
#  'image': 'https://shopping-phinf.pstatic.net/main_3999237/39992373021.20230513055543.jpg',
#  'lprice': '32890',
#  'hprice': '',
#  'mallName': '네이버',
#  'productId': '39992373021',
#  'productType': '1',
#  'brand': '몰스킨',
#  'maker': '몰스킨',
#  'category1': '생활/건강',
#  'category2': '문구/사무용품',
#  'category3': '다이어리/플래너',
#  'category4': '다이어리'}

# %%
import pandas as pd

def get_fields(json_data):
    title = [each["title"] for each in json_data["items"]]
    link = [each["link"] for each in json_data["items"]]
    lprice = [each["lprice"] for each in json_data["items"]]
    mallName = [each["mallName"] for each in json_data["items"]]

    result_pd = pd.DataFrame({
        "title" : title,
        "link" : link,
        "lprice" : lprice,
        "mallName" : mallName,
    }, columns=["title", "link", "lprice", "mallName"])
    return result_pd

# %%
get_fields(one_result)
# Out:
#                                                title  \
# 0           <b>몰스킨</b> 2024 위클리 18개월 다이어리 소프트커버 상품선택
# 1               <b>몰스킨</b> 클래식노트 플레인 소프트커버 포켓 Pocket
# 2       <b>몰스킨</b> 클래식노트 룰드 하이드레인저블루 소프트커버 포켓 Pocket
# 3          [<b>몰스킨</b>] 2023-24년 18개월 다이어리(데일리, 위클리)
# 4  시리즈 역시즌 50 series <b>몰스킨</b> 집업 아우터 셔츠 SASFW22...
#
#                                                 link  lprice     mallName
# 0  https://search.shopping.naver.com/gate.nhn?id=...   32890          네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...   21840          네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...   18200          네이버
# 3  https://search.shopping.naver.com/gate.nhn?id=...   35000  몰스킨공식온라인스토어
# 4  https://search.shopping.naver.com/gate.nhn?id=...  110270          네이버

# %% [markdown]
# ## (4) delete_tag()

# %%
def delete_tag(input_str):
    input_str = input_str.replace("<b>", "")
    input_str = input_str.replace("</b>", "")
    return input_str

# %%
import pandas as pd

def get_fields(json_data):
    title = [delete_tag(each["title"]) for each in json_data["items"]]
    link = [each["link"] for each in json_data["items"]]
    lprice = [each["lprice"] for each in json_data["items"]]
    mallName = [each["mallName"] for each in json_data["items"]]

    result_pd = pd.DataFrame({
        "title" : title,
        "lprice" : lprice,
        "link" : link,
        "mallName" : mallName,
    }, columns=["title", "lprice", "link", "mallName"])
    return result_pd

# %%
get_fields(one_result)
# Out:
#                                            title  lprice  \
# 0              몰스킨 2024 위클리 18개월 다이어리 소프트커버 상품선택   32890
# 1                  몰스킨 클래식노트 플레인 소프트커버 포켓 Pocket   21840
# 2          몰스킨 클래식노트 룰드 하이드레인저블루 소프트커버 포켓 Pocket   18200
# 3             [몰스킨] 2023-24년 18개월 다이어리(데일리, 위클리)   35000
# 4  시리즈 역시즌 50 series 몰스킨 집업 아우터 셔츠 SASFW22821KHL  110270
#
#                                                 link     mallName
# 0  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 3  https://search.shopping.naver.com/gate.nhn?id=...  몰스킨공식온라인스토어
# 4  https://search.shopping.naver.com/gate.nhn?id=...          네이버

# %%
url = gen_search_url("shop", "몰스킨", 1, 5)
json_result = get_result_onepage(url)
pd_result = get_fields(json_result)
# Out:
# [2023-07-14 12:20:07.464530] Url Request Success

# %%
pd_result
# Out:
#                                            title  lprice  \
# 0              몰스킨 2024 위클리 18개월 다이어리 소프트커버 상품선택   32890
# 1                  몰스킨 클래식노트 플레인 소프트커버 포켓 Pocket   21840
# 2          몰스킨 클래식노트 룰드 하이드레인저블루 소프트커버 포켓 Pocket   18200
# 3             [몰스킨] 2023-24년 18개월 다이어리(데일리, 위클리)   35000
# 4  시리즈 역시즌 50 series 몰스킨 집업 아우터 셔츠 SASFW22821KHL  110270
#
#                                                 link     mallName
# 0  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 3  https://search.shopping.naver.com/gate.nhn?id=...  몰스킨공식온라인스토어
# 4  https://search.shopping.naver.com/gate.nhn?id=...          네이버

# %% [markdown]
# ## (5) actMain()

# %%
for n in range(1, 1000, 100):
    print(n)
# Out:
# 1
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901

# %%
result_mol = []

for n in range(1, 1000, 100):
    url = gen_search_url("shop", "몰스킨", n, 100)
    json_result = get_result_onepage(url)
    pd_result = get_fields(json_result)

    result_mol.append(pd_result)

result_mol = pd.concat(result_mol)
# Out:
# [2023-07-14 12:20:07.803415] Url Request Success
# [2023-07-14 12:20:08.104925] Url Request Success
# [2023-07-14 12:20:08.402263] Url Request Success
# [2023-07-14 12:20:08.739391] Url Request Success
# [2023-07-14 12:20:09.015688] Url Request Success
# [2023-07-14 12:20:09.292754] Url Request Success
# [2023-07-14 12:20:09.658261] Url Request Success
# [2023-07-14 12:20:09.932840] Url Request Success
# [2023-07-14 12:20:10.221927] Url Request Success
# [2023-07-14 12:20:10.540324] Url Request Success

# %%
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     1000 non-null   object
#  1   lprice    1000 non-null   object
#  2   link      1000 non-null   object
#  3   mallName  1000 non-null   object
# dtypes: object(4)
# memory usage: 39.1+ KB

# %%
result_mol
# Out:
#                                                 title  lprice  \
# 0                   몰스킨 2024 위클리 18개월 다이어리 소프트커버 상품선택   32890
# 1                       몰스킨 클래식노트 플레인 소프트커버 포켓 Pocket   21840
# 2               몰스킨 클래식노트 룰드 하이드레인저블루 소프트커버 포켓 Pocket   18200
# 3                  [몰스킨] 2023-24년 18개월 다이어리(데일리, 위클리)   35000
# 4       시리즈 역시즌 50 series 몰스킨 집업 아우터 셔츠 SASFW22821KHL  110270
# ..                                                ...     ...
# 95            몰스킨 Book Journal 쉘 케이스 라지 6 75 x 9 75인치   59220
# 96  몰스킨 PRO 12 월간 2023 위클리 Vertical 플래너 Hard 커버 A4...   73920
# 97    FOLK Folk Lean Assembly Pant - 몰스킨 FP5909W-NVYM  149400
# 98                         몰스킨 무료각인 스퀘어드 노트 하드 A4 -블랙   45200
# 99                    3317957 Moleskine Rucksack - 커피  659060
#
#                                                  link     mallName
# 0   https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 1   https://search.shopping.naver.com/gate.nhn?id=...          네이버
# ...

# %%
result_mol.reset_index(drop=True, inplace=True)

# %%
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     1000 non-null   object
#  1   lprice    1000 non-null   object
#  2   link      1000 non-null   object
#  3   mallName  1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %%
result_mol.head()
# Out:
#                                            title  lprice  \
# 0              몰스킨 2024 위클리 18개월 다이어리 소프트커버 상품선택   32890
# 1                  몰스킨 클래식노트 플레인 소프트커버 포켓 Pocket   21840
# 2          몰스킨 클래식노트 룰드 하이드레인저블루 소프트커버 포켓 Pocket   18200
# 3             [몰스킨] 2023-24년 18개월 다이어리(데일리, 위클리)   35000
# 4  시리즈 역시즌 50 series 몰스킨 집업 아우터 셔츠 SASFW22821KHL  110270
#
#                                                 link     mallName
# 0  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 3  https://search.shopping.naver.com/gate.nhn?id=...  몰스킨공식온라인스토어
# 4  https://search.shopping.naver.com/gate.nhn?id=...          네이버

# %%
result_mol.tail()
# Out:
#                                                  title  lprice  \
# 995            몰스킨 Book Journal 쉘 케이스 라지 6 75 x 9 75인치   59220
# 996  몰스킨 PRO 12 월간 2023 위클리 Vertical 플래너 Hard 커버 A4...   73920
# 997    FOLK Folk Lean Assembly Pant - 몰스킨 FP5909W-NVYM  149400
# 998                         몰스킨 무료각인 스퀘어드 노트 하드 A4 -블랙   45200
# 999                    3317957 Moleskine Rucksack - 커피  659060
#
#                                                   link mallName
# 995  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 996  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 997  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 998  https://search.shopping.naver.com/gate.nhn?id=...      네이버
# 999  https://search.shopping.naver.com/gate.nhn?id=...      네이버

# %%
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     1000 non-null   object
#  1   lprice    1000 non-null   object
#  2   link      1000 non-null   object
#  3   mallName  1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %%
result_mol["lprice"] = result_mol["lprice"].astype("float")
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     1000 non-null   object
#  1   lprice    1000 non-null   float64
#  2   link      1000 non-null   object
#  3   mallName  1000 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 31.4+ KB

# %% [markdown]
# ## (5)to_excel()

# %%
# %pip install xlsxwriter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
writer = pd.ExcelWriter("../data/06_molskin_diary_in_naver_shop.xlsx", engine="xlsxwriter")
result_mol.to_excel(writer, sheet_name="Sheet1")

workbook = writer.book
worksheet = writer.sheets["Sheet1"]
worksheet.set_column("A:A", 4)
worksheet.set_column("B:B", 80)
worksheet.set_column("C:C", 10)
worksheet.set_column("D:D", 10)
worksheet.set_column("E:E", 50)
worksheet.set_column("F:F", 10)

worksheet.conditional_format("C2:C1001", {"type" : "3_color_scale"})
writer.close()

# %%
# !dir "..\data\06_molskin_diary_in_naver_shop.xlsx"
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 5C48-9388
#
#  C:\Users\fins6\Documents\ds_study\data 디렉터리
#
# 2023-07-14  오후 12:20            75,135 06_molskin_diary_in_naver_shop.xlsx
#                1개 파일              75,135 바이트
#                0개 디렉터리  153,271,676,928 바이트 남음

# %% [markdown]
# ## (6) 시각화

# %%
import seaborn as sns
import platform
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

path = "c:/Windows/Fonts/malgun.ttf"

if platform.system() == "Darwin":
    print("Hangul OK in your MAC!")
    rc("font", family="Arial Unicode MS")
elif platform.system() == "Windows":
    font_name = font_manager.FontProperties(fname=path).get_name()
    print("Hangul OK in your Windows!!!")
    rc("font", family=font_name)
else:
    print("Unknown system. sorry.")
plt.rcParams["axes.unicode_minus"] = False
# Out:
# Hangul OK in your Windows!!!

# %%
result_mol.head()
# Out:
#                                            title    lprice  \
# 0              몰스킨 2024 위클리 18개월 다이어리 소프트커버 상품선택   32890.0
# 1                  몰스킨 클래식노트 플레인 소프트커버 포켓 Pocket   21840.0
# 2          몰스킨 클래식노트 룰드 하이드레인저블루 소프트커버 포켓 Pocket   18200.0
# 3             [몰스킨] 2023-24년 18개월 다이어리(데일리, 위클리)   35000.0
# 4  시리즈 역시즌 50 series 몰스킨 집업 아우터 셔츠 SASFW22821KHL  110270.0
#
#                                                 link     mallName
# 0  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 3  https://search.shopping.naver.com/gate.nhn?id=...  몰스킨공식온라인스토어
# 4  https://search.shopping.naver.com/gate.nhn?id=...          네이버

# %%
plt.figure(figsize=(15, 6))
sns.countplot(
    x=result_mol["mallName"], #문법다름
    data = result_mol,
    palette = "RdYlGn",
    order = result_mol["mallName"].value_counts().index
)
plt.xticks(rotation=90)
plt.show()
